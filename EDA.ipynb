# %% [markdown]
# # Univariate, Bivariate and MultiVariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Cars93.csv")

# %%
df.shape
# Out:
# (93, 28)

# %%
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# pick only Model, Type, Price, Horsepower, EngineSize
df = df[['Model','Type','Price','Horsepower','EngineSize']]

# %%
df.head()
# Out:
#      Model     Type  Price  Horsepower  EngineSize
# 0  Integra    Small   15.9         140         1.8
# 1   Legend  Midsize   33.9         200         3.2
# 2       90  Compact   29.1         172         2.8
# 3      100  Midsize   37.7         172         2.8
# 4     535i  Midsize   30.0         208         3.5

# %%
df.shape
# Out:
# (93, 5)

# %% [markdown]
# ## Univariate Analysis

# %%
df['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
df_small_type = df.loc[df['Type']=='Small']
df_midsize_type = df.loc[df['Type'] == 'Midsize']
df_large_type = df.loc[df['Type'] == 'Large']

# %%
plt.plot(df_small_type['Horsepower'], np.zeros_like(df_small_type['Horsepower']),'x')
plt.plot(df_midsize_type['Horsepower'], np.zeros_like(df_midsize_type['Horsepower']),'o')
plt.plot(df_large_type['Horsepower'], np.zeros_like(df_large_type['Horsepower']),'*')
plt.xlabel('Horsepower')
plt.show()

# %%
df_midsize_type.columns
# Out:
# Index(['Model', 'Type', 'Price', 'Horsepower', 'EngineSize'], dtype='object')

# %%
df_midsize_type[['Model','Type','Price','EngineSize']][df_midsize_type['Horsepower'] > 250]
# Out:
#       Model     Type  Price  EngineSize
# 10  Seville  Midsize   40.1         4.6
# 47      Q45  Midsize   47.9         4.5

# %% [markdown]
# ## Bivairate Analysis

# %%
sns.FacetGrid(df, hue="Type",height=5).map(plt.scatter, "Horsepower","EngineSize").add_legend()
plt.show()
# Out:
# /home/kakashi/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df,hue="Type",height=5)
# Out:
# /home/kakashi/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['Model', 'Type', 'Price', 'Horsepower', 'EngineSize'], dtype='object')
